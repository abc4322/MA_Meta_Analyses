# %% [markdown]
# # Convert .Rmd to .ipynb

# %%
# install.packages("devtools")
# remove.packages("rlang")
# install.packages("rlang")
# devtools::install_github("mkearney/rmd2jupyter")
# install.packages("rmd2jupyter")
# library("rmd2jupyter")

# %%
# rmd to ipynb
# rmd2jupyter("Preprocessing Data for Meta-Analyses.Rmd")

# %%
# install.packages("rmarkdown")

# %% [markdown]
# # Preprocess data of raw covidence Export

# %%
raw.df <- read.csv("final_data_export.csv")

# %% [markdown]
# ## Install and load Dplyr

# %%
# install.packages("dplyr")
library("dplyr")
# install.packages("sjmisc")
library("sjmisc")
# for data manipulation with dplyr see: https://www.youtube.com/watch?v=Gvhkp-Yw65U
# for splitting 2 values in 1 cell see: https://www.youtube.com/watch?v=DiY8EqZDwoI at 3:17 (e.g. if 2 scales for 1 outcome)
# for joining 2 data frames see:        https://www.youtube.com/watch?v=DiY8EqZDwoI at 11:57
# Out:
# Attache Paket: 'dplyr'
#
#
# Die folgenden Objekte sind maskiert von 'package:stats':
#
#     filter, lag
#
#
# Die folgenden Objekte sind maskiert von 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "Paket 'sjmisc' wurde unter R Version 4.2.1 erstellt"
# Install package "strengejacke" from GitHub (`devtools::install_github("strengejacke/strengejacke")`) to load all sj-packages at once!

# %%
my.raw.df <- raw.df %>%
  filter(Reviewer.Name == "Robin Jacob", Study.design == "Passive RCT")

# %% [markdown]
# ## Drop unimportant columns by name

# %% [markdown]
# ### Remove column rages (first columns)

# %%
my.df <- my.raw.df %>%
  select(-Reviewer.Name:-Further.Information.inserted.in.Extraction.Form.)  # "-" indicates deleting these columns

# %% [markdown]
# ### Remove single column names and repeating names with ascending numbers (table headlines)

# %%
cols.pop.char <- c()

for (time.point in 0:4){
  cols.pop.char <- append(cols.pop.char,
                          sprintf("Population.Characteristics..Time.Point.%d..",
                                  time.point
                                  )
                          )
}

cols.outc.t <- c()

for (outc in 1:7){
  for (t in 0:3){
    cols.outc.t <- append(cols.outc.t,
                          sprintf("Outcome.%d..Time.Point.%d..",
                                  outc, t
                                  )
                          )
  }
}

remove.cols <- c("Dates.of.Measuring.Time.Points.",
                 cols.pop.char[],
                 "Between.Measuring.Time.Points..Duration.",
                 "Intervention.and.Comparisons.",
                 "Definition.of.Outcomes.",
                 "Measures.of.Outcomes.",
                 cols.outc.t[]
                 )

my.df <- my.df[, ! names(my.df) %in% remove.cols]

# %% [markdown]
# ## Create arrays and data frame lists from Covidence tables

# %%
# install.packages("sjmisc")  # for str_contains()
library("sjmisc")

# %% [markdown]
# ### Set basic parameters

# %%
nm.placeholder <- -999  # placeholder for values marked as nm (not mentioned)

flag.x.s.r <- 2
  # x.s.r = exact value (0), mean s (1), or mean r (2)
  # flag.x.s.r = 2 --> include all
  # flag.x.s.r = 1 --> only include mean s and exact values
  # flag.x.s.r = 0 --> include only exact vaules

study.no <- length(my.df[,"Study.ID"])

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Checking for digits and characters

# %%
# function returning TRUE if string contains no characters but digits instead
no.char.but.digit.inside <- function(value){
  !(str_contains(value, letters, logic = "OR") |
  str_contains(value, LETTERS, logic = "OR")) &
  grepl("\\d", value)
}

# function returning TRUE if string contains characters
char.inside <- function(value){
  str_contains(value, letters, logic = "OR") |
  str_contains(value, LETTERS, logic = "OR")
}

# %%
char.inside("mindfulness meditation")
# Out:
# [1] TRUE

# %% [markdown]
# #### For mean values

# %%
# extracts mean r and mean s values as double
get.all.means <- function(value){
  if (grepl("mean r", value)){
    extracted.value <- as.double(sub(" mean r.*", "", value))
        # extracts anything before " mean r" as double                 
  } else if (grepl("mean s", value)){
    extracted.value <- as.double(sub(" mean s.*", "", value))
  } else if (grepl("mean", value)){
    extracted.value <- NA
    cat("value ", value, " not added because mean only")
    cat("\n")
  } else {
    extracted.value <- value
  }
  extracted.value
}

# extracts mean s only as double
get.mean.s.only <- function(value){
    if (grepl("mean s", value)){
    extracted.value <- as.double(sub(" mean s.*", "", value))
  } else if (grepl("mean r", value)){
    extracted.value <- NA
    cat("value ", value, " not added because mean r")
    cat("\n")
  } else if (grepl("mean", value)){
    extracted.value <- NA
    cat("value ", value, " not added because mean only")
    cat("\n")
  } else {
    extracted.value <- value
  }
  extracted.value
}

# %% [markdown]
# #### Convert value from nm, NA, digit, or char

# %%
convert.value <- function(value, nm.placeholder, only.double = TRUE){
  na.value <- FALSE
  if (is.na(value)){
    na.value <- TRUE
  }
  if (na.value == TRUE){
    extracted.value <- NA
  } else {
    value <- as.character(value)
    if (value == "nm"){
      extracted.value <- nm.placeholder
    } else if (value == ""){
      extracted.value <- NA
    } else if (value == "^"){
      extracted.value <- value
        # extracts value after "<" as double 
    } else if (grepl("<", value)){
      extracted.value <- as.double(sub(".*<", "", value))
        # extracts value after "<" as double 
    } else if (grepl(">", value)){
      extracted.value <- as.double(sub(".*>", "", value))
    } else if (no.char.but.digit.inside(value)){
      if (grepl("-", value)){
        # like "0 - 40"
        extracted.value <- value
      } else {
        extracted.value <- as.double(value) 
      }
    } else if (char.inside(value)){
      if (flag.x.s.r == 2){
        extracted.value <- get.all.means(value)
      } else if (flag.x.s.r == 1){
        extracted.value <- get.mean.s.only(value)
      } else if ((flag.x.s.r == 0) & !(grepl("mean r", value) | grepl("mean s", value))){
        extracted.value <- NA
        if (grepl("mean", value)){
          cat("value ", value, " not added because mean only")
          cat("\n")
        }
      } else {
        if (only.double == TRUE){
          extracted.value <- NA
          cat("unknown case with char inside: ", value)
          cat("\n")
        } else {
          extracted.value <- value
        }
      }
    } else {
      cat("unknown case: ", value)
      cat("\n")
    }
  }
  extracted.value
}

# %% [markdown]
# #### For arrays

# %%
clean.and.shape.data.to.array <- function(
  my.df, start, end, dims, dimname.list, nm.placeholder, flag.x.s.r, study.no
  ){
  my.array <- array(rep(NA),
                    dim = dims,
                    dimnames = dimname.list
                    )
  my.data <- my.df %>%
    select(start:end)
  
  if (length(dims) == 6){
    for (study in 1:study.no){
      my.data.col.no = 1
      for (dim.4.elmnt in 1:dims[4]){
        for (mtrx in 1:dims[3]){
          for (row in 1:dims[1]){
            for (col in 1:dims[2]){
              value <- my.data[study, my.data.col.no]
              my.data.col.no <- my.data.col.no + 1
              if (grepl(",", value)){
                value.before.comma <- sub(",.*", "", value)
                  # extracts anything before "," as double
                my.array[row, col, mtrx, dim.4.elmnt, 1, study] <- convert.value(
                  value.before.comma, nm.placeholder
                  )
                value.after.comma <- sub(".*,", "", value)
                  # extracts anything after "," as double
                my.array[row, col, mtrx, dim.4.elmnt, 2, study] <- convert.value(
                  value.after.comma, nm.placeholder
                  )
              } else {
                my.array[row, col, mtrx, dim.4.elmnt, 1, study] <- convert.value(
                  value, nm.placeholder
                  )
              }
            }
          }
        }
      }
    }
  } else if (length(dims) == 5){
    for (study in 1:study.no){
      my.data.col.no = 1
      for (mtrx in 1:dims[3]){
        for (row in 1:dims[1]){
          for (col in 1:dims[2]){
            value <- my.data[study, my.data.col.no]
            my.data.col.no <- my.data.col.no + 1
            if (grepl(",", value)){
              value.before.comma <- (sub(",.*", "", value))
                # extracts anything before "," as double
              my.array[row, col, mtrx, 1, study] <- convert.value(
                value.before.comma, nm.placeholder
                )
              value.after.comma <- (sub(".*,", "", value))
                # extracts anything after "," as double
              my.array[row, col, mtrx, 2, study] <- convert.value(
                value.after.comma, nm.placeholder
                )
            } else {
              my.array[row, col, mtrx, 1, study] <- convert.value(
                value, nm.placeholder
                )
            }
          }
        }
      }
    }
  } else if (length(dims) <= 4){
    print("too low dim, use function for data frame")
  }
  my.array
}

# %% [markdown]
# #### For data frame lists

# %%
# create data frames out of 2D Tables (with rows and cols swapped)
clean.data.to.df.list.swap <- function(
  my.df, start, end, dims, list.names, dimname.list
  ){
  study.df <- data.frame(matrix(
    rep(NA),
    nrow = dims[1],
    ncol = dims[2]
  ))
  row.names(study.df) <- dimname.list[[1]]
  colnames(study.df) <- dimname.list[[2]]
  
  # create list of NA data frames of preferred shape
  study.df.list <- list()
  for (i in 1:length(list.names)){
    study.df.list <- append(study.df.list, list(study.df), 0)
  }
  names(study.df.list) <- list.names
  
  my.data <- my.df %>%
    select(start:end)
  
  # vector of my.data.col.no to swapped rows and cols of Covidence output
  my.data.col.no.swapped <- c()
  i <- 0
  j <- 1
  for (k in 1:dims[1]){
    i <- 0
    for (l in 1:dims[2]){
      my.data.col.no.swapped <- append(my.data.col.no.swapped, i * dims[1] + j)
      i <- i + 1
    }
    j <- j + 1 
  }
  # dims[1] = rows new, cols old
  # dims[2] = cols new, rows old
  
  # e.g., filling pattern for old 4 x 7 and new 7 x 4 data frame 
  ## 1, dims[1]+1, 2*dims[1]+1, 3*dims[1]+1, 4*dims[1]+1, 5*dims[1]+1, 6*dims[1]+1,
  ## 2, dims[1]+2, 2*dims[1]+2, 3*dims[1]+2, 4*dims[1]+2, 5*dims[1]+2, 6*dims[1]+2,
  ## x, x, x, x, x, x, x,
  ## x, x, x, x, x, x, x
  
  for (study in 1:study.no){
    m <- 1
    for (row in 1:dims[1]){
      for (col in 1:dims[2]){
        value <- my.data[study, my.data.col.no.swapped[m]]
        m <- m + 1
        study.df.list[[study]][row, col] <- convert.value(
          value, nm.placeholder, only.double = FALSE
          )
      }
    }
  }
  study.df.list
}

# %%
# create data frames out of 2D Tables
clean.data.to.df.list <- function(
  my.df, start, end, dims, list.names, dimname.list
  ){
  study.df <- data.frame(matrix(
    rep(NA),
    nrow = dims[1],
    ncol = dims[2]
  ))
  row.names(study.df) <- dimname.list[[1]]
  colnames(study.df) <- dimname.list[[2]]
  
  # create list of NA data frames of preferred shape
  study.df.list <- list()
  for (i in 1:length(list.names)){
    study.df.list <- append(study.df.list, list(study.df), 0)
  }
  names(study.df.list) <- list.names
  
  my.data <- my.df %>%
    select(start:end)
  
  for (study in 1:study.no){
    my.data.col.no <- 1
    for (row in 1:dims[1]){
      for (col in 1:dims[2]){
        value <- my.data[study, my.data.col.no]
        my.data.col.no <- my.data.col.no + 1
        study.df.list[[study]][row, col] <- convert.value(
          value, nm.placeholder, only.double = FALSE
          )
      }
    }
  }
  study.df.list
}

# %% [markdown]
# ### Arrays

# %% [markdown]
# #### means.SDs

# %%
dims <- c(4, 3, 4, 7, 2, study.no)

dimname.list <- list(c("Intervention.1", "Intervention.2", "Intervention.3", "Control"),
                     c("Mean", "SD", "n"),
                     c("T0", "T1", "T2", "T3"),
                     c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7"),
                     c("Scale.1", "Scale.2"),
                     my.df[,"Study.ID"])

start <- "Intervention.1.Mean.O1T0"
end <- "Control.or.Intervention.4.n.in.case.of.period.O7T3"

means.SDs.array <- clean.and.shape.data.to.array(
    my.df, start, end, dims, dimname.list, nm.placeholder, flag.x.s.r, study.no
)
# Out:
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(start)` instead of `start` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.
# Note: Using an external vector in selections is ambiguous.
# ℹ Use `all_of(end)` instead of `end` to silence this message.
# ℹ See <https://tidyselect.r-lib.org/reference/faq-external-vector.html>.
# This message is displayed once per session.

# %%
# use my.pop.char.array[,,"T0","Johnson-Waddell 2018"] as test for "", NA, "nm", "double"
#      [,1]  [,2] [,3] [,4]  [,5]
# [1,] "197" NA   NA   "197" 394 
# [2,] ""    ""   NA   ""    "nm"
# [3,] ""    NA   NA   ""    "nm"
# [4,] ""    NA   NA   ""    "" 
# make flag.x.s.r work --> done

# %%
means.SDs.array
# Out:
# , , T0, Outcome.1, Scale.1, Ratanasiripong 2015
#
#                 Mean   SD  n
# Intervention.1    NA   NA NA
# Intervention.2 17.24 4.16 NA
# Intervention.3    NA   NA NA
# Control        17.29 3.50 NA
#
# , , T1, Outcome.1, Scale.1, Ratanasiripong 2015
#
#                 Mean   SD  n
# Intervention.1    NA   NA NA
# Intervention.2 14.90 3.44 NA
# Intervention.3    NA   NA NA
# Control        16.74 4.71 NA
#
# , , T2, Outcome.1, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.1, Ratanasiripong 2015
#
#                 Mean   SD  n
# Intervention.1    NA   NA NA
# Intervention.2 25.45 7.80 NA
# Intervention.3    NA   NA NA
# Control        23.74 7.72 NA
#
# , , T1, Outcome.2, Scale.1, Ratanasiripong 2015
#
#                 Mean   SD  n
# Intervention.1 21.28 6.95 NA
# Intervention.2    NA   NA NA
# Intervention.3    NA   NA NA
# Control        24.74 9.91 NA
#
# , , T2, Outcome.2, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.1, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.1, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.1, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.2, Ratanasiripong 2015
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.1, Sloan 2016
#
#                   Mean      SD  n
# Intervention.1 20.3333 5.04315 21
# Intervention.2      NA      NA NA
# Intervention.3      NA      NA NA
# Control        19.6500 5.60334 20
#
# , , T1, Outcome.1, Scale.1, Sloan 2016
#
#                   Mean      SD  n
# Intervention.1 17.1429 5.45239 21
# Intervention.2      NA      NA NA
# Intervention.3      NA      NA NA
# Control        22.1000 4.25379 20
#
# , , T2, Outcome.1, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.1, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA 21
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA 20
#
# , , T1, Outcome.1, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA 21
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA 20
#
# , , T2, Outcome.1, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.2, Sloan 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.1, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.1, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.1, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.1, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.1, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.2, Nidich 2009
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.1, Barry 2019
#
#                Mean  SD  n
# Intervention.1 5.32 3.7 NA
# Intervention.2   NA  NA NA
# Intervention.3   NA  NA NA
# Control        7.52 6.8 NA
#
# , , T1, Outcome.1, Scale.1, Barry 2019
#
#                Mean  SD  n
# Intervention.1 4.05 3.9 NA
# Intervention.2   NA  NA NA
# Intervention.3   NA  NA NA
# Control        8.68 9.3 NA
#
# , , T2, Outcome.1, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.1, Barry 2019
#
#                Mean  SD  n
# Intervention.1 5.79 6.2 NA
# Intervention.2   NA  NA NA
# Intervention.3   NA  NA NA
# Control        5.37 7.1 NA
#
# , , T1, Outcome.2, Scale.1, Barry 2019
#
#                Mean  SD  n
# Intervention.1 3.85 4.9 NA
# Intervention.2   NA  NA NA
# Intervention.3   NA  NA NA
# Control        5.18 6.7 NA
#
# , , T2, Outcome.2, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 11.91 8.1 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        13.76 8.5 NA
#
# , , T1, Outcome.3, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1  9.00 6.3 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        13.58 9.4 NA
#
# , , T2, Outcome.3, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 13.53 3.1 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        13.97 3.0 NA
#
# , , T1, Outcome.4, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 14.97 2.3 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        13.87 3.0 NA
#
# , , T2, Outcome.4, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 13.47 2.6 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        14.05 2.3 NA
#
# , , T1, Outcome.5, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 14.68 2.3 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        14.08 2.3 NA
#
# , , T2, Outcome.5, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 16.41 3.6 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        17.03 3.9 NA
#
# , , T1, Outcome.6, Scale.1, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 18.73 3.0 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        15.95 4.5 NA
#
# , , T2, Outcome.6, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.1, Barry 2019
#
#                Mean  SD  n
# Intervention.1 8.44 2.4 NA
# Intervention.2   NA  NA NA
# Intervention.3   NA  NA NA
# Control        8.68 2.0 NA
#
# , , T1, Outcome.7, Scale.1, Barry 2019
#
#                Mean  SD  n
# Intervention.1 9.06 2.1 NA
# Intervention.2   NA  NA NA
# Intervention.3   NA  NA NA
# Control        8.73 2.3 NA
#
# , , T2, Outcome.7, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.1, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.1, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.1, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.2, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 21.17 3.4 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        20.74 2.6 NA
#
# , , T1, Outcome.3, Scale.2, Barry 2019
#
#                 Mean  SD  n
# Intervention.1 20.20 2.7 NA
# Intervention.2    NA  NA NA
# Intervention.3    NA  NA NA
# Control        20.63 2.9 NA
#
# , , T2, Outcome.3, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.2, Barry 2019
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.1, Chen 2013
#
#                Mean   SD  n
# Intervention.1 46.6 11.6 NA
# Intervention.2   NA   NA NA
# Intervention.3   NA   NA NA
# Control        46.2 11.5 NA
#
# , , T1, Outcome.1, Scale.1, Chen 2013
#
#                Mean   SD  n
# Intervention.1 41.4 10.4 NA
# Intervention.2   NA   NA NA
# Intervention.3   NA   NA NA
# Control        46.3 11.8 NA
#
# , , T2, Outcome.1, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.1, Chen 2013
#
#                Mean   SD  n
# Intervention.1 49.8 11.7 NA
# Intervention.2   NA   NA NA
# Intervention.3   NA   NA NA
# Control        47.5  9.8 NA
#
# , , T1, Outcome.2, Scale.1, Chen 2013
#
#                Mean   SD  n
# Intervention.1 48.0 11.4 NA
# Intervention.2   NA   NA NA
# Intervention.3   NA   NA NA
# Control        47.1  9.3 NA
#
# , , T2, Outcome.2, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.1, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.1, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.1, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.2, Chen 2013
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# ...
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.1, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.1, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.1, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.1, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.1, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.1, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.2, Toole 2016
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.1, Schulte-Frankenfeld 2021
#
#                 Mean   SD  n
# Intervention.1 24.93 5.88 NA
# Intervention.2    NA   NA NA
# Intervention.3    NA   NA NA
# Control        24.26 5.73 NA
#
# , , T1, Outcome.1, Scale.1, Schulte-Frankenfeld 2021
#
#                 Mean   SD  n
# Intervention.1 19.53 6.55 NA
# Intervention.2    NA   NA NA
# Intervention.3    NA   NA NA
# Control        23.82 6.17 NA
#
# , , T2, Outcome.1, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean   SD  n
# Intervention.1 6.19 1.37 NA
# Intervention.2   NA   NA NA
# Intervention.3   NA   NA NA
# Control        5.93 1.18 NA
#
# , , T1, Outcome.2, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean   SD  n
# Intervention.1 6.65 1.29 NA
# Intervention.2   NA   NA NA
# Intervention.3   NA   NA NA
# Control        6.04 1.41 NA
#
# , , T2, Outcome.2, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.1, Schulte-Frankenfeld 2021
#
#                 Mean   SD  n
# Intervention.1 33.67 6.29 NA
# Intervention.2    NA   NA NA
# Intervention.3    NA   NA NA
# Control        36.97 6.98 NA
#
# , , T1, Outcome.3, Scale.1, Schulte-Frankenfeld 2021
#
#                 Mean   SD  n
# Intervention.1 37.93 6.73 NA
# Intervention.2    NA   NA NA
# Intervention.3    NA   NA NA
# Control        36.53 6.64 NA
#
# , , T2, Outcome.3, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.1, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.1, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.1, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.1, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.1, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.2, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.2, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.2, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.2, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.3, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.3, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.3, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.3, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.4, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.4, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.4, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.4, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.5, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.5, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.5, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.5, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.6, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.6, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.6, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.6, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T0, Outcome.7, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T1, Outcome.7, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T2, Outcome.7, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA
#
# , , T3, Outcome.7, Scale.2, Schulte-Frankenfeld 2021
#
#                Mean SD  n
# Intervention.1   NA NA NA
# Intervention.2   NA NA NA
# Intervention.3   NA NA NA
# Control          NA NA NA

# %% [markdown]
# #### Results Quantitative

# %%
dims <- c(7, 3, 3, 6, 2, study.no)

dimname.list <- list(c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7"),
                     c("P.Value", "Effect.Size", "Effect.Size.CI"),
                     c("T1", "T2", "T3"),
                     c("Int1.X.Int2", "Int1.X.Int3", "Int1.X.Int4", "Int2.X.Int3", "Int2.X.Int4", "Int3.X.Int4"),
                     c("Scale.1", "Scale.2"),
                     my.df[,"Study.ID"]
                     )

start <- "Outcome.1.P.Value.1x2T1"
end <- "Outcome.7.Confidence.Interval.of.Effect.Size.3x4T3"

results.quantitative.array <- clean.and.shape.data.to.array(
    my.df, start, end, dims, dimname.list, nm.placeholder, flag.x.s.r, study.no
)

# %% [markdown]
# ### Data frame lists

# %% [markdown]
# #### Intervention Comparison

# %%
dims <- c(4, 7)

list.names <- my.df[,"Study.ID"]

dimname.list <- list(c("Intervention.1", "Intervention.2", "Intervention.3", "Control"),
                     c("Name", "Short.Description", "Delivery.Mode", "Meditation.App", "Sessions.Duration.in.minutes",
                       "Frequency.in.times.per.week", "Total.Duration.in.Days")
                     )
start <- "Name.Intervention.1"
end <- "Total.Duration.of.Intervention.in.Days.Control.or.Intervention.4"

intervention.comparisons.df.list <- clean.data.to.df.list.swap(
 my.df, start, end, dims, list.names, dimname.list
)
intervention.comparisons.df.list
# Out:
# value  0.99 mean  not added because mean only
# value  36.67 mean  not added because mean only
# value  3.79 during intervention, 2.04 during follow-up mean  not added because mean only
# value  4.19 mean  not added because mean only
# value  12.5 mean  not added because mean only
# value  2.5 mean  not added because mean only
# value  11.19 mean  not added because mean only
# value  2.82 mean  not added because mean only
# $`Ratanasiripong 2015`
#                                  Name Short.Description Delivery.Mode
# Intervention.1                   <NA>                NA            NA
# Intervention.2 mindfulness meditation                NA            NA
# Intervention.3                   <NA>                NA            NA
# Control               no intervention                NA            NA
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           NA
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                     NA
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Sloan 2016`
#                                Name
# Intervention.1 breathing meditation
# Intervention.2                 <NA>
# Intervention.3                 <NA>
# Control             no intervention
#                                           Short.Description
# Intervention.1 "guided audio-recorded breathing meditation"
# Intervention.2                                         <NA>
# Intervention.3                                         <NA>
# Control                                                <NA>
#                                                                       Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App), audio recording
# Intervention.2                                                                 <NA>
# Intervention.3                                                                 <NA>
# Control                                                                        <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                            9
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                     56
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Nidich 2009`
#                                           Name
# Intervention.1  Transcendental meditation (TM)
# Intervention.2                            <NA>
# Intervention.3                            <NA>
# Control                      wait-list control
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Short.Description
# Intervention.1 "The TM technique [...] that allows the\nordinary thinking process to become more quiescent and a\nunique psychophysiologic state of “restful alertness” to be\ngained.28 This distinctive state of restful alertness,28,29 is char-\nacterized by decreased respiration rates, sympathetic tone and\nhypothalamic–pituitary–adrenal axis activity,30,31 and high\nelectroencephalography coherence.32"\n"The TM technique was taught in a seven-step course33 as\nfollows: (i) group introductory lecture on potential benefits\nand previous research (90 min); (ii) group preparatory lec-\nture, discussing the mechanics and origin of the TM tech-\nnique (90 min); (iii) personal interview (10 min); (iv) personal\ninstruction session (90 min); (v–vii) group “verification and\nvalidation of the practice” sessions on 3 consecutive days fol-\nlowing personal instruction, verifying correctness of TM prac-\ntice, and providing the understanding of the mechanics of the\nTM technique"
# Intervention.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <NA>
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <NA>
# Control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <NA>
#                Delivery.Mode Meditation.App Sessions.Duration.in.minutes
# Intervention.1          -999             NA                           20
# Intervention.2            NA             NA                           NA
# Intervention.3            NA             NA                           NA
# Control                   NA             NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                        -999                     90
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Barry 2019`
#                              Name
# Intervention.1 intervention group
# Intervention.2               <NA>
# Intervention.3               <NA>
# Control        usual care control
#                                                                                                                                                                                                                                                                                                                                                                                     Short.Description
# Intervention.1                                                                                 - spoken guided mindfulness practice of breath awarenes\n\n"The survey questionnaire and a sealed\ntrial pack (including mindfulness CD, instructions,\nand record sheet for the intervention group [...]) were posted to the participants."\n"spoken guided mindfulness practice of\nbreath awarenes"
# Intervention.2                                                                                                                                                                                                                                                                                                                                                                                   <NA>
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                   <NA>
# Control        - no intervention\n- requested to not meditate else where\n\n"an\nempty CD case and information sheet was included\nfor the control group"\n"Participants allocated to the control were given no\nintervention activities for the same period and while\nnot discouraged from their usual form of self-care,\nthey were requested not to undertake any regular\nmindfulness practice."
#                                                      Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App)
# Intervention.2                                                <NA>
# Intervention.3                                                <NA>
# Control                                                       <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           30
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                           5                     56
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Chen 2013`
#                                   Name
# Intervention.1        meditation group
# Intervention.2                    <NA>
# Intervention.3                    <NA>
# Control        no intervention control
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Short.Description
# Intervention.1 - concentrate on breathing\n- eyes closed\n- non-judgmentally\n- become aware of their thoughts, feelings, and sensations \n- emphasis on the use of “internal eyes”\n- body scan\n\n"On day 1, participants were taught how to concentrate on breathing\nwith their eyes closed, and to non-judgmentally become aware of their\nthoughts, feelings, and sensations while focusing on the flow of breath\nthrough the nostrils (Wallace, 2006). "\n"This practice incorporated\ntraditional Chinese Buddhist cultural concepts, 5 such as emphasis on the\nuse of “internal eyes” to scan bodily sensations, according to the method\nused in an empirical study (Yang et al., 2011)."
# Intervention.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   <NA>
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   <NA>
# Control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <NA>
#                                          Delivery.Mode Meditation.App
# Intervention.1 nm but probably synchronous in presence             NA
# Intervention.2                                    <NA>             NA
# Intervention.3                                    <NA>             NA
# Control                                           <NA>             NA
#                Sessions.Duration.in.minutes Frequency.in.times.per.week
# Intervention.1                           30                           7
# Intervention.2                           NA                          NA
# Intervention.3                           NA                          NA
# Control                                  NA                          NA
#                Total.Duration.in.Days
# Intervention.1                      7
# Intervention.2                     NA
# Intervention.3                     NA
# Control                            NA
#
# $`Warnecke 2011`
#                                                  Name
# Intervention.1 Audio CD guided mindfulness meditation
# Intervention.2                                   <NA>
# Intervention.3                                   <NA>
# Control                                      waitlist
#                         Short.Description
# Intervention.1 "mindfulness intervention"
# Intervention.2                       <NA>
# Intervention.3                       <NA>
# Control                              <NA>
#                                                                Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App), audio CD
# Intervention.2                                                          <NA>
# Intervention.3                                                          <NA>
# Control                                                                 <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           30
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                      3.3375                     56
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Johnson-Waddell 2018`
#                                  Name
# Intervention.1 mindfulness meditation
# Intervention.2                   <NA>
# Intervention.3                   <NA>
# Control               no intervention
#                                                                                                                                                         Short.Description
# Intervention.1 "participants were sent links to the mindfulness meditation training online through email, and\nlistened to the guided meditations online through YouTube"
# Intervention.2                                                                                                                                                       <NA>
# Intervention.3                                                                                                                                                       <NA>
# Control                                                                                                                                                              <NA>
#                                                                     Delivery.Mode
# Intervention.1 Youtube Video, Asynchronous guiding by a recorded voice (e.g. App)
# Intervention.2                                                               <NA>
# Intervention.3                                                               <NA>
# Control                                                                      <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           10
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                        -999                     35
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Plummer 2018`
#                                        Name
# Intervention.1 Mindfulness-Based Curriculum
# Intervention.2                         <NA>
# Intervention.3                         <NA>
# Control                     no intervention
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Short.Description
# Intervention.1 "Module 1: Enduring understanding—mindfulness of body\n1.1 Introduction and what mindfulness is not\n1.2 What mindfulness is/science of mindfulness\n1.3 Embodiment: body as a source of unending\ninformation and intuition\n1.4 Embodiment/building self-awareness/directed\nneuroplasticity\nModule 2: Enduring understanding—mindfulness of\nemotions\n2.1 Emotional landscape: identifying and experiencing the\nphysiological aspects of emotion\n2.2 The skill of opening to negative/unpleasant/\nchallenging emotions\n2.3 The skill of opening to positive/pleasant emotions\n2.4 Developing empathy and compassion for ourselves\nand our emotional experiences\n2.5 Empathy and compassion for the emotional\nexperiences of others in the clinical setting\nModule 3: Enduring understanding—mindfulness of mind\n3.1 Recognizing story-interpretation vs reality/experience\n3.2 Awareness of thoughts (judging, planning, anticipating,\nworrying)\n3.3 Discerning appropriate use of mind\n3.4 Restoration of awe (invariant cortical representations)\n3.5 Applying appropriate use of mind in the clinical setting\nModule 4: Enduring understanding—mindfulness of\nexperience\n4.1 The pause: from compulsion/autopilot to\nchoice/presence\n4.2 Recognizing sensations, emotions, thoughts\n4.3 Learning to be with what is\n4.4 Moving from reacting to responding skillfully in the\nclinical setting\n4.5 Reflection and integration: living and working mindfully"
# Intervention.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        <NA>
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        <NA>
# Control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               <NA>
#                                                                 Delivery.Mode
# Intervention.1 nm but probably Synchronous guiding in presence (e.g. seminar)
# Intervention.2                                                           <NA>
# Intervention.3                                                           <NA>
# Control                                                                  <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           90
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                        -999                    140
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Janowiak 1994`
#                             Name Short.Description
# Intervention.1 mantra meditation                NA
# Intervention.2         Shavasana                NA
# Intervention.3              <NA>                NA
# Control             no-treatment                NA
#                                                                                                       Delivery.Mode
# Intervention.1 Self-conducted meditation, nm but probably Synchronous online guiding on the internet (e.g. webinar)
# Intervention.2 Self-conducted meditation, nm but probably Synchronous online guiding on the internet (e.g. webinar)
# Intervention.3                                                                                                 <NA>
# Control                                                                                                        <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                         -999
# Intervention.2             NA                         -999
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                        -999                     56
# Intervention.2                        -999                     56
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Oman 2007`
#                              Name
# Intervention.1               <NA>
# Intervention.2 Passage Meditation
# Intervention.3               <NA>
# Control         wait-list control
#                                                                                                                                                                                                                                                                                                             Short.Description
# Intervention.1                                                                                                                                                                                                                                                                                                           <NA>
# Intervention.2 "form of sitting meditation"\n"also offers corollary\npractices and supports for deepening meditation and for integrating meditative states of mind\ninto daily living"\n"Focused attention; Recalling the\nmind to a cue word; etc. Slowing down; Detachment; etc.Readings reflecting meditative perspective"
# Intervention.3                                                                                                                                                                                                                                                                                                           <NA>
# Control                                                                                                                                                                                                                                                                                                                  <NA>
#                                                                 Delivery.Mode
# Intervention.1                                                           <NA>
# Intervention.2 nm but probably Synchronous guiding in presence (e.g. seminar)
# Intervention.3                                                           <NA>
# Control                                                                  <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           NA
# Intervention.2             NA                           90
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                     NA
# Intervention.2                           1                     56
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Weytens 2014`
#                                      Name
# Intervention.1                       <NA>
# Intervention.2 loving-kindness meditation
# Intervention.3                       <NA>
# Control                 wait-list control
#                                                                                                                                                                                                                                                                                                                                                                                                                                           Short.Description
# Intervention.1                                                                                                                                                                                                                                                                                                                                                                                                                                         <NA>
# Intervention.2 "This training was a\nFrench adaptation of the training proposed by Fredrickson et al.\n[65]"\n"The longer session duration was achieved by adding\nbasic meditation exercises as well as by increasing the duration of\nthe ‘‘on-site’’ LKM exercises and of their debriefing. As in the\nFredrickson et al. study [65], the LKM group participants were\nasked to practice 20 minutes of meditation at home, at least five\ndays a week. "
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                                                                         <NA>
# Control                                                                                                                                                                                                                                                                                                                                                                                                                                                <NA>
#                                                                                        Delivery.Mode
# Intervention.1                                                                                  <NA>
# Intervention.2 nm probably Synchronous guiding in presence (e.g. seminar), Self-conducted meditation
# Intervention.3                                                                                  <NA>
# Control                                                                                         <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           NA
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                     NA
# Intervention.2                           6                     42
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Bonamo 2015`
#                                       Name
# Intervention.1 20-min body scan meditation
# Intervention.2 45-min body scan meditation
# Intervention.3                        <NA>
# Control               no-treatment control
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                Short.Description
# Intervention.1 - similar to 45-min group\n- fewer and shorter pauses than 45-min group\n- played by computer speakers\n\n"with fewer and shorter pauses in the 20-min version and less\ndetail in the different areas of the body (e.g., the 20-min\nversion calls attention to all of the fingers of each hand\ncollectively, whereas the 45-min scan focuses on each finger\nindividually)"\n"The recordings were played to participants\nthrough external computer speakers."
# Intervention.2                                                                                                                                                                                                                                                                                                                                                - played by computer speakers\n\n"The recordings were played to participants\nthrough external computer speakers."
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                                                                                              <NA>
# Control                                                                                                                                                                                                                                                                                                                                                                                                                                                                     <NA>
#                                                      Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App)
# Intervention.2                                                <NA>
# Intervention.3                                                <NA>
# Control                                                       <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           20
# Intervention.2             NA                           45
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                           1                      1
# Intervention.2                           1                      1
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Smith 2021`
#                             Name
# Intervention.1   10% Happier App
# Intervention.2              <NA>
# Intervention.3              <NA>
# Control        wait-list contorl
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Short.Description
# Intervention.1 "The practices include mindfulness of the sensations\nof the breath, mindfulness toward sensations and experiences\nof the body, and mindfulness toward the contents of the mind.\nIn addition, the meditations encourage the practitioner to use\nthe skill of mental noting to label their mental contents."\n"The meditation\npractices in these modules included mindfulness toward the\nsensations of the body and breath, coupled with other practices\naimed at cultivating awareness and understanding of emotions\nas mental contents and the nonjudgmental stance toward\nemotions, with a goal of optimizing the response to one’s"\nemotions"
# Intervention.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      <NA>
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      <NA>
# Control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             <NA>
#                                                     Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App
# Intervention.2                                               <NA>
# Intervention.3                                               <NA>
# Control                                                      <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1    10% Happier                        10.97
# Intervention.2           <NA>                           NA
# Intervention.3           <NA>                           NA
# Control                  <NA>                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                       22.85                     56
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Wang 2021`
#                                          Name
# Intervention.1                           <NA>
# Intervention.2 short-term meditation training
# Intervention.3                           <NA>
# Control                       no intervention
#                                                                                                                                                                                                                                                                                                                             Short.Description
# Intervention.1                                                                                                                                                                                                                                                                                                                           <NA>
# Intervention.2 "The instructions, de-\nlivered via an audio-recording of a woman researcher’s voice,\nfocused on teaching naïve participants the step-by-step prac-\ntice of meditation without any spiritual or religious emphasis."\n"MT [Meditation Training] content was a continuum from FA [Focused Attention] to OM [Open Monitoring].
# Intervention.3                                                                                                                                                                                                                                                                                                                           <NA>
# Control                                                                                                                                                                                                                                                                                                                                  <NA>
#                                                      Delivery.Mode
# Intervention.1                                                <NA>
# Intervention.2 Asynchronous guiding by a recorded voice (e.g. App)
# Intervention.3                                                <NA>
# Control                                                       <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           NA
# Intervention.2             NA                           20
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                     NA
# Intervention.2                           4                      4
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Fish 2019`
#                             Name
# Intervention.1     Headspace App
# Intervention.2              <NA>
# Intervention.3              <NA>
# Control        business as usual
#                                                                                                                                                                                                                                                              Short.Description
# Intervention.1 "The program educates users how to perform mindfulness medita-\ntion (see Figure 1), provides guided meditations (see Figure 2), and provides 10 free\nsessions. For this study, we utilized the free sessions to ensure participants encoun-\ntered no costs."
# ...
# Intervention.2                                                                                                                                                      <NA>
# Intervention.3                                                                                                                                                      <NA>
# Control                                                                                                                                                             <NA>
#                                                      Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App)
# Intervention.2                                                <NA>
# Intervention.3                                                <NA>
# Control                                                       <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1      Headspace                           10
# Intervention.2           <NA>                           NA
# Intervention.3           <NA>                           NA
# Control                  <NA>                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                     NA
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Dorais 2021`
#                                Name
# Intervention.1 centering meditation
# Intervention.2                 <NA>
# Intervention.3                 <NA>
# Control                   waitlist
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Short.Description
# Intervention.1 "Centering meditation is based on an early Christian mystic\npractice called centering prayer developed by the Desert Fathers\nand Mothers in the third century (Keating, 2002). The focus\nof centering prayer is interior silence which the early Christian\nmystics to develop deeper communion with God. Like other\nconcentration meditations that use a symbol for focus (Goleman,\n1988), practitioners select a word or symbol they hold sacred\n(e.g., Shalom, hope) and use it to bring back their mind from\ndistractions. However, unlike many other meditations, centering\nprayer focuses not on the mind but rather areas of spiritual\nconnection. In completative texts, it is called the “return of\nthe heart” (Pennington, 1980, p. 62) or “attention of the heart”\n(Bourgeault, 2004, p. 113). The term centering stems from the\nidea that the meditator finds their core center and awakens to\nawareness of divine presence inside them."\n\n"1. Select a word or symbol that you consider spiritually\ngrounding for you (e.g., a name for God or spiritual concepts\nlike Shalom, hope, or joy) and represents your intention to\nconnect with what is spiritual to you.\n2. At the beginning of the meditation, sit down comfortably with\nyour eyes closed (preferably away from external distractions)\nand silently introduce your sacred word or symbol.\n3. After you do this, you’ll probably notice distracting thoughts\nemerging or mind wandering. That’s okay. When you notice\nyourself becoming distracted, just ever-so-gently reintroduce\nyour sacred word or symbol.\n4. At the end of your meditation, just sit and rest in silence or say\na prayer for a few moments."
# Intervention.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   <NA>
# Intervention.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   <NA>
# Control                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          <NA>
#                        Delivery.Mode Meditation.App
# Intervention.1 online training video             NA
# Intervention.2                  <NA>             NA
# Intervention.3                  <NA>             NA
# Control                         <NA>             NA
#                Sessions.Duration.in.minutes Frequency.in.times.per.week
# Intervention.1                         -999                           9
# Intervention.2                           NA                          NA
# Intervention.3                           NA                          NA
# Control                                  NA                          NA
#                Total.Duration.in.Days
# Intervention.1                     28
# Intervention.2                     NA
# Intervention.3                     NA
# Control                            NA
#
# $`Toole 2016`
#                                               Name
# Intervention.1 self-compassion meditation training
# Intervention.2                                <NA>
# Intervention.3                                <NA>
# Control                           waitlist control
#                                                                                                                                                                                                                                                                                                                       Short.Description
# Intervention.1 "three\nexercises included a compassionate body scan (completed first in\nthe lab and then sent to participants the following two days), an\naffectionate breathing exercise (sent to participants on Days 4 and\n5), and a loving-kindness meditation directed toward the body\n(sent to participants on Days 6 and 7)"
# Intervention.2                                                                                                                                                                                                                                                                                                                     <NA>
# Intervention.3                                                                                                                                                                                                                                                                                                                     <NA>
# Control                                                                                                                                                                                                                                                                                                                            <NA>
#                                                      Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App)
# Intervention.2                                                <NA>
# Intervention.3                                                <NA>
# Control                                                       <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1             NA                           20
# Intervention.2             NA                           NA
# Intervention.3             NA                           NA
# Control                    NA                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                      7
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA
#
# $`Schulte-Frankenfeld 2021`
#                             Name
# Intervention.1       Balloon App
# Intervention.2              <NA>
# Intervention.3              <NA>
# Control        wait-list control
#                                                                                                                                                                                                      Short.Description
# Intervention.1 "The training course particularly assembled for this study was designed to cover major prin-\nciples of mindfulness, stress and coping, happiness in live, meta-cognition, self-care and com-\npassion"
# Intervention.2                                                                                                                                                                                                    <NA>
# Intervention.3                                                                                                                                                                                                    <NA>
# Control                                                                                                                                                                                                           <NA>
#                                                      Delivery.Mode
# Intervention.1 Asynchronous guiding by a recorded voice (e.g. App)
# Intervention.2                                                <NA>
# Intervention.3                                                <NA>
# Control                                                       <NA>
#                Meditation.App Sessions.Duration.in.minutes
# Intervention.1        Balloon                           NA
# Intervention.2           <NA>                           NA
# Intervention.3           <NA>                           NA
# Control                  <NA>                           NA
#                Frequency.in.times.per.week Total.Duration.in.Days
# Intervention.1                          NA                     57
# Intervention.2                          NA                     NA
# Intervention.3                          NA                     NA
# Control                                 NA                     NA

# %% [markdown]
# #### Dates of Measuring Time Points

# %%
dims <- c(4, 1)

list.names <- my.df[,"Study.ID"]

dimname.list <- list(c("Time.Point.0", "Time.Point.1", "Time.Point.2", "Time.Point.3"),
                     c("Date")
                     )
start <- "Time.Point.0.Date"
end <- "Time.Point.3.Date"

dates.measuring.time.points.df.list <- clean.data.to.df.list(
 my.df, start, end, dims, list.names, dimname.list
)
dates.measuring.time.points.df.list
# Out:
# $`Ratanasiripong 2015`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Sloan 2016`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Nidich 2009`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Barry 2019`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Chen 2013`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Warnecke 2011`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Johnson-Waddell 2018`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Plummer 2018`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Janowiak 1994`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Oman 2007`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Weytens 2014`
#                                        Date
# Time.Point.0 1 week before the intervention
# Time.Point.1 2 weeks after the intervention
# Time.Point.2                           <NA>
# Time.Point.3                           <NA>
#
# $`Bonamo 2015`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Smith 2021`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Wang 2021`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Fish 2019`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Siembor 2018`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Lee 2018`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Bultas 2021`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Huberty 2019`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Tanner 2009`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`deGrace 1976`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Messer 2016`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Vasiliauskas 2013`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Nolan 2020`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Dorais 2021`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Toole 2016`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA
#
# $`Schulte-Frankenfeld 2021`
#              Date
# Time.Point.0   NA
# Time.Point.1   NA
# Time.Point.2   NA
# Time.Point.3   NA

# %% [markdown]
# #### Between-Measuring Time Points Duration

# %%
dims <- c(3, 1)

list.names <- my.df[,"Study.ID"]

dimname.list <- list(c("Time.Point.0...1", "Time.Point.0...2", "Time.Point.0...3"),
                     c("Duration.in.Days")
                     )
start <- "Time.Point.0...1.Duration.in.Days"
end <- "Time.Point.0...3.Duration.in.Days"

between.T.duration.df.list <- clean.data.to.df.list(
 my.df, start, end, dims, list.names, dimname.list
)
between.T.duration.df.list
# Out:
# value  7 mean  not added because mean only
# $`Ratanasiripong 2015`
#                  Duration.in.Days
# Time.Point.0...1               28
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Sloan 2016`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Nidich 2009`
#                  Duration.in.Days
# Time.Point.0...1               90
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Barry 2019`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Chen 2013`
#                  Duration.in.Days
# Time.Point.0...1                6
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Warnecke 2011`
#                  Duration.in.Days
# Time.Point.0...1               56
# Time.Point.0...2              112
# Time.Point.0...3               NA
#
# $`Johnson-Waddell 2018`
#                  Duration.in.Days
# Time.Point.0...1             45.5
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Plummer 2018`
#                  Duration.in.Days
# Time.Point.0...1               70
# Time.Point.0...2              140
# Time.Point.0...3              224
#
# $`Janowiak 1994`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Oman 2007`
#                  Duration.in.Days
# Time.Point.0...1               56
# Time.Point.0...2              112
# Time.Point.0...3               NA
#
# $`Weytens 2014`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Bonamo 2015`
#                  Duration.in.Days
# Time.Point.0...1                0
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Smith 2021`
#                  Duration.in.Days
# Time.Point.0...1               56
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Wang 2021`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Fish 2019`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Siembor 2018`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Lee 2018`
#                  Duration.in.Days
# Time.Point.0...1               28
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Bultas 2021`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Huberty 2019`
#                  Duration.in.Days
# Time.Point.0...1               56
# Time.Point.0...2               84
# Time.Point.0...3               NA
#
# $`Tanner 2009`
#                  Duration.in.Days
# Time.Point.0...1            91.25
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`deGrace 1976`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Messer 2016`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Vasiliauskas 2013`
#                  Duration.in.Days
# Time.Point.0...1               21
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Nolan 2020`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Dorais 2021`
#                  Duration.in.Days
# Time.Point.0...1               13
# Time.Point.0...2               27
# Time.Point.0...3               NA
#
# $`Toole 2016`
#                  Duration.in.Days
# Time.Point.0...1               NA
# Time.Point.0...2               NA
# Time.Point.0...3               NA
#
# $`Schulte-Frankenfeld 2021`
#                  Duration.in.Days
# Time.Point.0...1               57
# Time.Point.0...2               NA
# Time.Point.0...3               NA

# %% [markdown]
# #### Definition of Outcomes

# %%
dims <- c(7, 1)

list.names <- my.df[,"Study.ID"]

dimname.list <- list(c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7"),
                     c("Definition")
                     )
start <- "Outcome.1.Definition"
end <- "Outcome.7.Definition"

outcome.definitions.df.list <- clean.data.to.df.list(
 my.df, start, end, dims, list.names, dimname.list
)
outcome.definitions.df.list
# Out:
# $`Ratanasiripong 2015`
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Definition
# Outcome.1                                                                                                                                                                                                                                                                                                                      "Lazarus and Folkman (1984) asserted that a psychological\nexperience of stress results when a situation is perceived to be\nharmful or exceeding one’s resources"
# Outcome.2 "Anxiety can be seen as\nrelatively related to stress, in that it can be aggravated by the\npresence of prolonged stress and multiple stressors. Anxiety is\na state of apprehension and an out-of-proportion response to a\nperceived threat, which can disrupt psychological functioning\nand manifest as physiological symptoms, such as elevated blood\npressure, sweating, dizziness, or increased heartbeat (Editors of\nthe American Heritage Dictionaries, 2007; Lewis, 1970)."
# Outcome.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <NA>
# Outcome.4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <NA>
# Outcome.5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <NA>
# Outcome.6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <NA>
# Outcome.7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    <NA>
#
# $`Sloan 2016`
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Definition
# Outcome.1 "The definition of stress varies somewhat throughout the literature; however, most\ndefinitions appear to be grounded in the individual work of Hans Selye (1956), a\nprominent endocrinologist, and Richard S. Lazarus (1966), a well-known psychologist\nboth interested in the scholarship of stress. The generally accepted definition attributed to\nLazarus defines stress as the emotional response when life “demands exceed the personal\nand social resources the individual is able to mobilize” (Stress Management from Mind\nTools, n.d., para. 7).\nAccording to the American Institute of Stress (American Institute of Stress [AIS],\nn.d.) stress can be categorized as (a) acute, an episodic stress experience exhibited as an\nimmediate fight or flight response to circumstances such as earning a bad grade or\nfrustration with a roommate; (b) chronic, ongoing and often ignored experiences that may\nbe triggered by issues such as tuition bills and unhappy relationships; (c) eustress, stress\nassociated with positive events such as an athletic performance or excitement about an\nupcoming event; or, (d) distress, constant daily stress related to depression and financial\ndifficulties that cannot be disregarded. All types of stress may have a physiological\nresponse, but chronic stress is the primary culprit as it is ongoing stress that has not been\nreconciled. Virtually all body systems are vulnerable to stress including the nervous,\nmusculoskeletal, respiratory, cardiovascular, endocrine, gastrointestinal, and reproductive\nsystems (AIS, n.d.)."
# Outcome.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <NA>
# Outcome.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <NA>
# Outcome.4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <NA>
# Outcome.5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <NA>
# Outcome.6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <NA>
# Outcome.7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 <NA>
#
# $`Nidich 2009`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Barry 2019`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4       -999
# Outcome.5       -999
# Outcome.6       -999
# Outcome.7       -999
#
# $`Chen 2013`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Warnecke 2011`
#                                                                                                                                                                 Definition
# Outcome.1 "Psychological stress has been defined as occurring\nwhen an individual perceives that environmental\ndemands tax or exceed his or her adaptive capac-\nity. 19"
# Outcome.2                                                                                                                                                             -999
# Outcome.3                                                                                                                                                             -999
# Outcome.4                                                                                                                                                             <NA>
# Outcome.5                                                                                                                                                             <NA>
# Outcome.6                                                                                                                                                             <NA>
# Outcome.7                                                                                                                                                             <NA>
#
# $`Johnson-Waddell 2018`
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Definition
# Outcome.1 "Shapiro et al. (2006) proposed a theory of mindfulness using\nthe IAA model (intention, awareness, and attitude), where the three axioms of intention (doing\nsomething on purpose), awareness (focusing attention on), and attitude (mindfulness qualities\nsuch as acceptance, openness, and lack of judgment) occur at the same time; moment by\nmoment. This process of mindfulness is believed to lead to a change in perspective, or\nreperceiving, which is a meta-mechanism of action that leads to change and positive outcomes\n(Shapiro et al., 2006). Within this meta-mechanism are direct mechanisms of “(1) self-\nregulation, (2) values clarification, (3) cognitive, emotional, and behavioral flexibility, and (4)\nexposure” (Shapiro et al., p. 377). Mindfulness allows one to separate oneself from one’s\nthoughts and view life’s circumstances and situations as distinct from the self. Shapiro et al.\ntermed mindfulness as reperceiving because it entails a shift in perspective from being involved\nin our life to be a witness of it; being able to extricate oneself from the drama to being able to\nobjectively look at thoughts and feelings and shift how they are understood and perceived."
# Outcome.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <NA>
# Outcome.3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <NA>
# Outcome.4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <NA>
# Outcome.5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <NA>
# Outcome.6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <NA>
# Outcome.7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  <NA>
#
# $`Plummer 2018`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4       -999
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Janowiak 1994`
#           Definition
# Outcome.1       -999
# Outcome.2         NA
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Oman 2007`
#           Definition
# Outcome.1       -999
# Outcome.2         NA
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Weytens 2014`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Bonamo 2015`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Smith 2021`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Wang 2021`
#           Definition
# Outcome.1       -999
# Outcome.2         NA
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Fish 2019`
#           Definition
# Outcome.1       -999
# Outcome.2         NA
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Siembor 2018`
#                                                                                                                                                                                              Definition
# Outcome.1 "Mindfulness (MF) is defined as an intentional nonjudgmental\nawareness of present-moment experiences such as thoughts, feelings, and body sensations (e.g.,\nBaer, 2003; Kabat-Zinn, 2003)."
# Outcome.2                        "Psychological stress\nis defined as when a person believes that environmental demands exceed his or her adaptive\ncapacity (Cohen, Janicki-Deverts, & Miller, 2007)."
# Outcome.3                                                                                                                                                                                          <NA>
# Outcome.4                                                                                                                                                                                          <NA>
# Outcome.5                                                                                                                                                                                          <NA>
# Outcome.6                                                                                                                                                                                          <NA>
# Outcome.7                                                                                                                                                                                          <NA>
#
# $`Lee 2018`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4       -999
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Bultas 2021`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Huberty 2019`
#                                                                                                                                             Definition
# Outcome.1                                                                                                                                         -999
# Outcome.2 "Mindfulness is defined as the state of\nbeing attentive to and aware of what is taking place in the\npresent moment without judgement [30]"
# Outcome.3                                                                                                                                         -999
# Outcome.4                                                                                                                                         <NA>
# Outcome.5                                                                                                                                         <NA>
# Outcome.6                                                                                                                                         <NA>
# Outcome.7                                                                                                                                         <NA>
#
# $`Tanner 2009`
#                                                                                                                                                                                              Definition
# Outcome.1 "Mindfulness may be thought of as ‘‘focusing one’s attention in a nonjudgmental or\naccepting way on the experience occurring in the present moment’’ (Baer, Smith, &\nAllen, 2004, p. 191)."
# Outcome.2                                                                                                                                                                                          <NA>
# Outcome.3                                                                                                                                                                                          <NA>
# Outcome.4                                                                                                                                                                                          <NA>
# Outcome.5                                                                                                                                                                                          <NA>
# Outcome.6                                                                                                                                                                                          <NA>
# Outcome.7                                                                                                                                                                                          <NA>
#
# $`deGrace 1976`
#           Definition
# Outcome.1       -999
# Outcome.2         NA
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Messer 2016`
#                                                                                                                                                                                                                                   Definition
# Outcome.1                                                                                                                                                                                                                               -999
# Outcome.2 "Mindfulness has been described as “the awareness that\nemerges through paying attention on purpose, in the present\nmoment, and nonjudgementally to the unfolding of experi-\nence moment by moment” (Kabat-Zinn, 2003, p. 145)."
# Outcome.3                                                                                                                                                                                                                               <NA>
# Outcome.4                                                                                                                                                                                                                               <NA>
# Outcome.5                                                                                                                                                                                                                               <NA>
# Outcome.6                                                                                                                                                                                                                               <NA>
# Outcome.7                                                                                                                                                                                                                               <NA>
#
# $`Vasiliauskas 2013`
#           Definition
# Outcome.1       -999
# Outcome.2         NA
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Nolan 2020`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3       -999
# Outcome.4       -999
# Outcome.5       -999
# Outcome.6         NA
# Outcome.7         NA
#
# $`Dorais 2021`
#           Definition
# Outcome.1       -999
# Outcome.2       -999
# Outcome.3         NA
# Outcome.4         NA
# Outcome.5         NA
# Outcome.6         NA
# Outcome.7         NA
#
# $`Toole 2016`
#                                                                                                              Definition
# Outcome.1 "self-compassion includes three interconnected elements: mindful-\nness, self-kindness, and common humanity."
# Outcome.2                                                                                                          -999
# Outcome.3                                                                                                          <NA>
# Outcome.4                                                                                                          <NA>
# Outcome.5                                                                                                          <NA>
# Outcome.6                                                                                                          <NA>
# Outcome.7                                                                                                          <NA>
#
# $`Schulte-Frankenfeld 2021`
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Definition
# Outcome.1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            -999
# Outcome.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            -999
# Outcome.3 "defined as a mode of awareness evoked when attention is directed\npurposefully to the immediate experience while perpetuating a mental stance of acceptance\n(Bishop et al., 2004)"\n"assumed to be a common capacity of humans, the\nability to deliberately evoke a mode of mindfulness in situations in which it would be beneficial\ncan be improved through training. Mechanisms proposed to underlie this ability include\nenhanced awareness of present-moment experiences (‘attention monitoring’) and an affective\nprocessing style oriented towards acceptance (‘acceptance’) (Lindsay & Creswell, 2017). "\n"mindfulness understood as a holistic secular concept"
# Outcome.4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <NA>
# Outcome.5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <NA>
# Outcome.6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <NA>
# Outcome.7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            <NA>

# %% [markdown]
# #### Measures of Outcomes

# %%
dims <- c(7, 3)

list.names <- my.df[,"Study.ID"]

dimname.list <- list(c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7"),
                     c("Measures.Name", "Start.and.End.Point", "High.or.low.means.resilient")
                     )
start <- "Outcome.1.Scale.s.or.other.Measure.s.Name"
end <- "Outcome.7.High.or.low.means.resilient"

outcome.measures.df.list <- clean.data.to.df.list(
 my.df, start, end, dims, list.names, dimname.list
)
outcome.measures.df.list
# Out:
# $`Ratanasiripong 2015`
#                                                                                                              Measures.Name
# Outcome.1                                                Perceived Stress Scale (PSS; Cohen, Kamarck, & Mermelstein, 1983)
# Outcome.2 State Anxiety Scale from the State–Trait Anxiety Inventory (Spielberger, Gorsuch, Lushene, Vagg, & Jacobs, 1983)
# Outcome.3                                                                                                             <NA>
# Outcome.4                                                                                                             <NA>
# Outcome.5                                                                                                             <NA>
# Outcome.6                                                                                                             <NA>
# Outcome.7                                                                                                             <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                        -999
# Outcome.2                  NA                          NA
# Outcome.3                  NA                          NA
# Outcome.4                  NA                          NA
# Outcome.5                  NA                          NA
# Outcome.6                  NA                          NA
# Outcome.7                  NA                          NA
#
# $`Sloan 2016`
#                              Measures.Name Start.and.End.Point
# Outcome.1 The Perceived Stress Scale (PSS)              0 - 40
# Outcome.2                             <NA>                <NA>
# Outcome.3                             <NA>                <NA>
# Outcome.4                             <NA>                <NA>
# Outcome.5                             <NA>                <NA>
# Outcome.6                             <NA>                <NA>
# Outcome.7                             <NA>                <NA>
#           High.or.low.means.resilient
# Outcome.1                           v
# Outcome.2                        <NA>
# Outcome.3                        <NA>
# Outcome.4                        <NA>
# Outcome.5                        <NA>
# Outcome.6                        <NA>
# Outcome.7                        <NA>
#
# $`Nidich 2009`
#                                                         Measures.Name
# Outcome.1 Profile of Mood States total mood disturbance main scale 23
# Outcome.2                     Profile of Mood States anxiety subscale
# Outcome.3                  Profile of Mood States depression subscale
# Outcome.4                                                        <NA>
# Outcome.5                                                        <NA>
# Outcome.6                                                        <NA>
# Outcome.7                                                        <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                        -999
# Outcome.2                -999                        -999
# Outcome.3                -999                        -999
# Outcome.4                  NA                          NA
# Outcome.5                  NA                          NA
# Outcome.6                  NA                          NA
# Outcome.7                  NA                          NA
#
# $`Barry 2019`
#                                                                                 Measures.Name
# Outcome.1                                     Depression, Anxiety\nand Stress Scale (DASS) 26
# Outcome.2                                     Depression, Anxiety\nand Stress Scale (DASS) 26
# Outcome.3 Depression, Anxiety\nand Stress Scale (DASS) 26, Perceived Stress Scale\n(PSS)27,28
# Outcome.4                                       Psychological Capital\nQuestionnaire (PCQ) 19
# Outcome.5                                       Psychological Capital\nQuestionnaire (PCQ) 19
# Outcome.6                                       Psychological Capital\nQuestionnaire (PCQ) 19
# Outcome.7                                       Psychological Capital\nQuestionnaire (PCQ) 19
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1               0 - 9                        -999
# Outcome.2               0 - 7                        -999
# Outcome.3          0 - 14, nm                        -999
# Outcome.4                -999                        -999
# Outcome.5                -999                        -999
# Outcome.6                -999                        -999
# Outcome.7                -999                        -999
#
# $`Chen 2013`
#                                                    Measures.Name
# Outcome.1           Self-Rating Anxiety Scale (SAS) (Zung, 1971)
# Outcome.2 Self-Rating Depression Scale (SDS) (Zung et al., 1965)
# Outcome.3                                                   <NA>
# Outcome.4                                                   <NA>
# Outcome.5                                                   <NA>
# Outcome.6                                                   <NA>
# Outcome.7                                                   <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1             20 - 80                        -999
# Outcome.2             20 - 80                        -999
# Outcome.3                <NA>                          NA
# Outcome.4                <NA>                          NA
# Outcome.5                <NA>                          NA
# Outcome.6                <NA>                          NA
# Outcome.7                <NA>                          NA
#
# $`Warnecke 2011`
#                                                                                       Measures.Name
# Outcome.1 Perceived Stress Scale (PSS), Depression Anxiety and Stress Scale (DASS) - Stress Subcale
# Outcome.2                           Depression Anxiety and Stress Scale (DASS) - Depression Subcale
# Outcome.3                              Depression Anxiety and Stress Scale (DASS) - Anxiety Subcale
# Outcome.4                                                                                      <NA>
# Outcome.5                                                                                      <NA>
# Outcome.6                                                                                      <NA>
# Outcome.7                                                                                      <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1      0 - 40, 0 - 42                        v, v
# Outcome.2              0 - 42                           v
# Outcome.3              0 - 42                           v
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Johnson-Waddell 2018`
#                                                                 Measures.Name
# Outcome.1 Mindfulness Attention Awareness Scale (MAAS) (Brown and Ryan (2003)
# Outcome.2                                                                <NA>
# Outcome.3                                                                <NA>
# Outcome.4                                                                <NA>
# Outcome.5                                                                <NA>
# Outcome.6                                                                <NA>
# Outcome.7                                                                <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1             15 - 90                           v
# Outcome.2                <NA>                        <NA>
# Outcome.3                <NA>                        <NA>
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Plummer 2018`
#                                                                             Measures.Name
# Outcome.1                                                 Perceived Stress Scale (PSS).16
# Outcome.2                      Cognitive and Affective Mindfulness Scale-Revised (CAMS-R)
# Outcome.3                  World Health Organization Quality of Life-Brief (WHO-QOL-BREF)
# Outcome.4 Cognitive and Affective Mindfulness Scale-Revised (CAMS-R) - acceptace subscale
# Outcome.5                                                                            <NA>
# Outcome.6                                                                            <NA>
# Outcome.7                                                                            <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                        -999
# Outcome.2                  60                        -999
# Outcome.3                -999                        -999
# Outcome.4                -999                        -999
# Outcome.5                  NA                          NA
# Outcome.6                  NA                          NA
# Outcome.7                  NA                          NA
#
# $`Janowiak 1994`
#           Measures.Name Start.and.End.Point High.or.low.means.resilient
# Outcome.1          -999                  NA                          NA
# Outcome.2            NA                  NA                          NA
# Outcome.3            NA                  NA                          NA
# Outcome.4            NA                  NA                          NA
# Outcome.5            NA                  NA                          NA
# Outcome.6            NA                  NA                          NA
# Outcome.7            NA                  NA                          NA
#
# $`Oman 2007`
#                                                                                                                                   Measures.Name
# Outcome.1 scales adapted from a\nwell-known set of brief measures developed by the Fetzer Institute (1999, pp. 86–87) - positve coping subscale
# Outcome.2                                                                                                                                  <NA>
# Outcome.3                                                                                                                                  <NA>
# Outcome.4                                                                                                                                  <NA>
# Outcome.5                                                                                                                                  <NA>
# Outcome.6                                                                                                                                  <NA>
# Outcome.7                                                                                                                                  <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1               0 - 9                           ^
# Outcome.2                <NA>                        <NA>
# Outcome.3                <NA>                        <NA>
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Weytens 2014`
#                                      Measures.Name Start.and.End.Point
# Outcome.1 Satisfaction with Life Scale (SWLS [71])              5 - 35
# Outcome.2     Beck Depression Inventory (BDI [72])             13 - 52
# Outcome.3         erceived Stress Scale (PSS [74])              0 - 50
# Outcome.4                                     <NA>                <NA>
# Outcome.5                                     <NA>                <NA>
# Outcome.6                                     <NA>                <NA>
# Outcome.7                                     <NA>                <NA>
#           High.or.low.means.resilient
# Outcome.1                        -999
# Outcome.2                        -999
# Outcome.3                           v
# Outcome.4                        <NA>
# Outcome.5                        <NA>
# Outcome.6                        <NA>
# Outcome.7                        <NA>
#
# $`Bonamo 2015`
#                                  Measures.Name Start.and.End.Point
# Outcome.1  The Toronto Mindfulness Scale (TMS)              0 - 72
# Outcome.2 State-Trait Anxiety Inventory (STAI)             20 - 80
# Outcome.3                                 <NA>                <NA>
# Outcome.4                                 <NA>                <NA>
# Outcome.5                                 <NA>                <NA>
# Outcome.6                                 <NA>                <NA>
# Outcome.7                                 <NA>                <NA>
#           High.or.low.means.resilient
# Outcome.1                           ^
# Outcome.2                           v
# Outcome.3                        <NA>
# Outcome.4                        <NA>
# Outcome.5                        <NA>
# Outcome.6                        <NA>
# Outcome.7                        <NA>
#
# $`Smith 2021`
#                                                           Measures.Name
# Outcome.1 Depression Anxiety and Stress Scale [32] - depression subcale
# Outcome.2    Depression Anxiety and Stress Scale [32] - anxiety subcale
# Outcome.3     Depression Anxiety and Stress Scale [32] - stress subcale
# Outcome.4                                                          <NA>
# Outcome.5                                                          <NA>
# Outcome.6                                                          <NA>
# Outcome.7                                                          <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1              0 - 42                           v
# Outcome.2              0 - 42                           v
# Outcome.3              0 - 42                           v
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Wang 2021`
#                                                 Measures.Name
# Outcome.1 State-Trait Anxiety Inventory (S-TAI) - state (SAI)
# Outcome.2                                                <NA>
# Outcome.3                                                <NA>
# Outcome.4                                                <NA>
# Outcome.5                                                <NA>
# Outcome.6                                                <NA>
# Outcome.7                                                <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                           v
# Outcome.2                  NA                        <NA>
# Outcome.3                  NA                        <NA>
# Outcome.4                  NA                        <NA>
# Outcome.5                  NA                        <NA>
# Outcome.6                  NA                        <NA>
# Outcome.7                  NA                        <NA>
#
# $`Fish 2019`
#                                                             Measures.Name
# Outcome.1 Patient Health Questionnaire-9 (PHQ-9; Kroenke & Spitzer, 2002)
# Outcome.2                                                            <NA>
# Outcome.3                                                            <NA>
# Outcome.4                                                            <NA>
# Outcome.5                                                            <NA>
# Outcome.6                                                            <NA>
# Outcome.7                                                            <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                           v
# Outcome.2                  NA                        <NA>
# Outcome.3                  NA                        <NA>
# Outcome.4                  NA                        <NA>
# Outcome.5                  NA                        <NA>
# Outcome.6                  NA                        <NA>
# Outcome.7                  NA                        <NA>
#
# $`Siembor 2018`
#                                                                                                            Measures.Name
# Outcome.1 Cognitive and Affective Mindfulness Scale–Revised (CAMS-R; Feldman, Hayes, Kumar, Greeson, & Laurenceau, 2007)
# Outcome.2                                           Perceived Stress Scale (PSS-10; Cohen, Kamarck, & Mermelstein, 1983)
# Outcome.3                                                                                                           <NA>
# Outcome.4                                                                                                           <NA>
# Outcome.5                                                                                                           <NA>
# Outcome.6                                                                                                           <NA>
# Outcome.7                                                                                                           <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                           ^
# Outcome.2              0 - 40                           v
# Outcome.3                <NA>                        <NA>
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Lee 2018`
#                                                                Measures.Name
# Outcome.1                                       Perceived Stress Scale (PSS)
# Outcome.2              State-Trait Anxiety Inventory (STAI) - state subscale
# Outcome.3              State-Trait Anxiety Inventory (STAI) - trait subscale
# Outcome.4 Quick Inventory of Depressive Symptomatology Self-Report (QIDS-SR)
# Outcome.5                                                               <NA>
# Outcome.6                                                               <NA>
# Outcome.7                                                               <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1              0 - 40                        -999
# Outcome.2             20 - 80                        -999
# Outcome.3             20 - 80                        -999
# Outcome.4              0 - 27                        -999
# Outcome.5                <NA>                          NA
# Outcome.6                <NA>                          NA
# Outcome.7                <NA>                          NA
#
# $`Bultas 2021`
#                                                                     Measures.Name
# Outcome.1                       Perceived Stress Scale (PSS) (Cohen et al., 1983)
# Outcome.2 Connor-Davidson Resilience Scale (CD-RISC-10) (Connor & Davidson, 2003)
# Outcome.3       Mindfulness Attention Awareness Scale (MAAS) (Brown & Ryan, 2003)
# Outcome.4                                                                    <NA>
# Outcome.5                                                                    <NA>
# Outcome.6                                                                    <NA>
# Outcome.7                                                                    <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                        -999
# Outcome.2                -999                           ^
# Outcome.3                -999                           ^
# Outcome.4                  NA                        <NA>
# Outcome.5                  NA                        <NA>
# Outcome.6                  NA                        <NA>
# Outcome.7                  NA                        <NA>
#
# $`Huberty 2019`
#                                                Measures.Name
# Outcome.1               Perceived Stress Scale (PSS) [58,59]
# Outcome.2 Five Factor Mindfulness Questionnaire (FFMQ) [60].
# Outcome.3         Self-Compassion Survey Short-Form (SCS-SF)
# Outcome.4                                               <NA>
# Outcome.5                                               <NA>
# Outcome.6                                               <NA>
# Outcome.7                                               <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1              0 - 40                           v
# Outcome.2            39 - 195                           ^
# Outcome.3             12 - 60                           ^
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Tanner 2009`
#                                                                Measures.Name
# Outcome.1 Kentucky Inventory of Mindfulness Skills (KIMS; Baer et al., 2004)
# Outcome.2                                                               <NA>
# Outcome.3                                                               <NA>
# Outcome.4                                                               <NA>
# Outcome.5                                                               <NA>
# Outcome.6                                                               <NA>
# Outcome.7                                                               <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1            39 - 195                           ^
# Outcome.2                <NA>                        <NA>
# Outcome.3                <NA>                        <NA>
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`deGrace 1976`
#                                                                                                  Measures.Name
# Outcome.1 California Psychological Inventory French version (CPI) (Gough 1957) - Subscale Self-acceptance (Sa)
# Outcome.2                                                                                                 <NA>
# Outcome.3                                                                                                 <NA>
# Outcome.4                                                                                                 <NA>
# Outcome.5                                                                                                 <NA>
# Outcome.6                                                                                                 <NA>
# Outcome.7                                                                                                 <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                  NA                          NA
# Outcome.2                  NA                          NA
# Outcome.3                  NA                          NA
# Outcome.4                  NA                          NA
# Outcome.5                  NA                          NA
# Outcome.6                  NA                          NA
# Outcome.7                  NA                          NA
#
# $`Messer 2016`
#                                                                                           Measures.Name
# Outcome.1                          The Perceived Stress Scale (PSS; Cohen, Kamark, & Mermelstein, 1983)
# Outcome.2 Five Facet Mindfulness Questionnaire (FFMQ; Baer, Smith, Hopkins, Krietemeyer, & Toney, 2006)
# Outcome.3                                                                                          <NA>
# Outcome.4                                                                                          <NA>
# Outcome.5                                                                                          <NA>
# Outcome.6                                                                                          <NA>
# Outcome.7                                                                                          <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                           v
# Outcome.2                -999                        -999
# Outcome.3                  NA                        <NA>
# Outcome.4                  NA                        <NA>
# Outcome.5                  NA                        <NA>
# Outcome.6                  NA                        <NA>
# Outcome.7                  NA                        <NA>
#
# $`Vasiliauskas 2013`
#                                                                          Measures.Name
# Outcome.1 Batson Empathy Adjectives (BEA; Batson, 1986; Coke, Batson, & McDavis, 1978)
# Outcome.2                                                                         <NA>
# Outcome.3                                                                         <NA>
# Outcome.4                                                                         <NA>
# Outcome.5                                                                         <NA>
# Outcome.6                                                                         <NA>
# Outcome.7                                                                         <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                        -999
# Outcome.2                  NA                          NA
# Outcome.3                  NA                          NA
# Outcome.4                  NA                          NA
# Outcome.5                  NA                          NA
# Outcome.6                  NA                          NA
# Outcome.7                  NA                          NA
#
# $`Nolan 2020`
#                                                                                 Measures.Name
# Outcome.1                        Cognitive and Affective Mindfulness Scale – Revised (CAMS-R)
# Outcome.2                                Depression, Anxiety, and Stress Scale – 21 (DASS-21)
# Outcome.3                                Depression, Anxiety, and Stress Scale – 21 (DASS-21)
# Outcome.4 Depression, Anxiety, and Stress Scale – 21 (DASS-21),\nPerceived Stress Scale (PSS)
# Outcome.5                                                 Satisfaction with Life Scale (SWLS)
# Outcome.6                                                                                <NA>
# Outcome.7                                                                                <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1             12 - 48                           ^
# Outcome.2              0 - 42                           v
# Outcome.3              0 - 42                           v
# Outcome.4      0 - 42, 0 - 40                        v, v
# Outcome.5              5 - 35                        -999
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Dorais 2021`
#                                                                               Measures.Name
# Outcome.1                                  Perceived Stress Scale (PSS; Cohen et al., 1994)
# Outcome.2 Cognitive and Affective Mindfulness\nScale-Revised (CAMS-R; Feldman et al., 2007)
# Outcome.3                                                                              <NA>
# Outcome.4                                                                              <NA>
# Outcome.5                                                                              <NA>
# Outcome.6                                                                              <NA>
# Outcome.7                                                                              <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1                -999                        -999
# Outcome.2               1- 48                           ^
# Outcome.3                <NA>                        <NA>
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Toole 2016`
#                                                 Measures.Name
# Outcome.1            Self-Compassion Scale (SCS; Neff, 2003a)
# Outcome.2 Rosenberg Self-Esteem Scale (RSES; Rosenberg, 1965)
# Outcome.3                                                <NA>
# Outcome.4                                                <NA>
# Outcome.5                                                <NA>
# Outcome.6                                                <NA>
# Outcome.7                                                <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1            26 - 130                           ^
# Outcome.2             10 - 40                           ^
# Outcome.3                <NA>                        <NA>
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>
#
# $`Schulte-Frankenfeld 2021`
#                                                                                                        Measures.Name
# Outcome.1                                                              Perceived Stress Scale (PSS-10) (Cohen, 2017)
# Outcome.2 Questionnaire for the Assessment of Happiness ( ger.: Lebensglückskala, LSS) (Ciccarello & Reinhard, 2014)
# Outcome.3                                          Freiburg Mindfulness Inventory (FMI-14) (Buchheld & Walach, 2002)
# Outcome.4                                                                                                       <NA>
# Outcome.5                                                                                                       <NA>
# Outcome.6                                                                                                       <NA>
# Outcome.7                                                                                                       <NA>
#           Start.and.End.Point High.or.low.means.resilient
# Outcome.1              0 - 40                           v
# Outcome.2              9 - 81                           ^
# Outcome.3             14 - 56                           ^
# Outcome.4                <NA>                        <NA>
# Outcome.5                <NA>                        <NA>
# Outcome.6                <NA>                        <NA>
# Outcome.7                <NA>                        <NA>

# %% [markdown]
# #### Qualitative Results of Data Analyses

# %%
dims <- c(7, 3)

list.names <- my.df[,"Study.ID"]

dimname.list <- list(c("Key.Theme.1", "Key.Theme.2", "Key.Theme.3", "Key.Theme.4", "Key.Theme.5", "Key.Theme.6", "Key.Theme.7"),
                     c("Name.of.Key.Theme", "Description.of.Key.Theme", "Results")
                     )
start <- "Key.Theme.1.Name.of.Key.Theme"
end <- "Key.Theme.7.Results"

results.qualitative.df.list <- clean.data.to.df.list(
 my.df, start, end, dims, list.names, dimname.list
)
results.qualitative.df.list
# Out:
# $`Ratanasiripong 2015`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Sloan 2016`
#                       Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1 See "Table 18. Major Codes"                       NA      NA
# Key.Theme.2                        <NA>                       NA      NA
# Key.Theme.3                        <NA>                       NA      NA
# Key.Theme.4                        <NA>                       NA      NA
# Key.Theme.5                        <NA>                       NA      NA
# Key.Theme.6                        <NA>                       NA      NA
# Key.Theme.7                        <NA>                       NA      NA
#
# $`Nidich 2009`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Barry 2019`
#                                       Name.of.Key.Theme
# Key.Theme.1    Self-reported stress during trial period
# Key.Theme.2 Self-Stress-Management during\ntrial period
# Key.Theme.3                                        <NA>
# Key.Theme.4                                        <NA>
# Key.Theme.5                                        <NA>
# Key.Theme.6                                        <NA>
# Key.Theme.7                                        <NA>
#                                                                                                                                                                                                                                    Description.of.Key.Theme
# Key.Theme.1                                                                                                                                                   Question: "Did you experience any stress related to your\nPhD during the last 8-week period?"
# Key.Theme.2 Question: "Did you undertake or receive any other support\nwith the aim to reduce stress related to your PhD during the last 8-week period? If so, please describe below and outline whether this helped you to cope\nwith your stress levels."
# Key.Theme.3                                                                                                                                                                                                                                            <NA>
# Key.Theme.4                                                                                                                                                                                                                                            <NA>
# Key.Theme.5                                                                                                                                                                                                                                            <NA>
# Key.Theme.6                                                                                                                                                                                                                                            <NA>
# Key.Theme.7                                                                                                                                                                                                                                            <NA>
#                                                                                                                                                                                                                                                                                          Results
# Key.Theme.1                                                                                see table 2\n- "more partici-\npants in the intervention group reported experiencing\nstress during this period."\n- " most frequent type of\nstress reported was due to “general work processes”\n\n
# Key.Theme.2 see table 3\n- "approximately\nthe same number of strategies were reported in total\nby the control and intervention group participants"\n- "intervention group reporting more physical modes of\nsupport and the control group reporting more support\nfrom the academic community"
# Key.Theme.3                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.4                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.5                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.6                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.7                                                                                                                                                                                                                                                                                 <NA>
#
# $`Chen 2013`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Warnecke 2011`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Johnson-Waddell 2018`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Plummer 2018`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Janowiak 1994`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Oman 2007`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Weytens 2014`
#                                                  Name.of.Key.Theme
# Key.Theme.1 Reasons for quiting loving kindness meditation program
# Key.Theme.2                                                   <NA>
# Key.Theme.3                                                   <NA>
# Key.Theme.4                                                   <NA>
# Key.Theme.5                                                   <NA>
# Key.Theme.6                                                   <NA>
# Key.Theme.7                                                   <NA>
#                                    Description.of.Key.Theme
# Key.Theme.1 There was a high dropout rate in this condition
# Key.Theme.2                                            <NA>
# Key.Theme.3                                            <NA>
# Key.Theme.4                                            <NA>
# Key.Theme.5                                            <NA>
# Key.Theme.6                                            <NA>
# Key.Theme.7                                            <NA>
#                                                                                                                                                                                                                                                                                                          Results
# Key.Theme.1 - "incongruity between the proposed technique and their personality"\ne.g. - ‘‘I am too impatient for this type of exercise,’’\n- ‘‘Meditation\nstresses me, I am not comfortable with this type of method,’’\n- ‘‘If I\nhad known that we were going to meditate, I would not have\nsigned up’’\n\n
# Key.Theme.2                                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.3                                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.4                                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.5                                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.6                                                                                                                                                                                                                                                                                                 <NA>
# Key.Theme.7                                                                                                                                                                                                                                                                                                 <NA>
#
# $`Bonamo 2015`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Smith 2021`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Wang 2021`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Fish 2019`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Siembor 2018`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Lee 2018`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Bultas 2021`
#                                      Name.of.Key.Theme
# Key.Theme.1       Subjective Definition of Mindfulness
# Key.Theme.2 Participants' perception of mindful People
# Key.Theme.3                        Intervention effect
# Key.Theme.4                                       <NA>
# Key.Theme.5                                       <NA>
# Key.Theme.6                                       <NA>
# Key.Theme.7                                       <NA>
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Description.of.Key.Theme
# Key.Theme.1                                                                                                                                                                                                                           "All 49 students responded with a basic knowl-\nedge of mindfulness and described mindfulness in terms such\nas being “self-aware,” “in control” of their emotions, “fo -\ncused,” and “attentive” to self and surroundings. Participants\nidentified multiple themes."
# Key.Theme.2                                                                                                                                                                                                                                                                                        "Participant themes related to individuals who used mind-\nfulness included descriptions of being calmed and relaxed (Calm), confident (Confident), and aware of self and their sur -\nroundings (Aware)."
# Key.Theme.3 "Postintervention, the experimental group identified more\nbenefits of mindfulness and reported having more plans for\nfuture use than the control group. Identified benefits included\ncalming to help relieve stress and anxiety (Calm) and increased\nfocus and awareness of thoughts and emotions (Focus). Barri-\ners to mindfulness included lack of time (Time) as well as both\ninternal (e.g., mental health concerns) and external distractions\n(e.g., noise and space) distractions."
# Key.Theme.4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <NA>
# Key.Theme.5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <NA>
# Key.Theme.6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <NA>
# Key.Theme.7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              <NA>
#             Results
# Key.Theme.1      NA
# Key.Theme.2      NA
# Key.Theme.3      NA
# Key.Theme.4      NA
# Key.Theme.5      NA
# Key.Theme.6      NA
# Key.Theme.7      NA
#
# $`Huberty 2019`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Tanner 2009`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`deGrace 1976`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Messer 2016`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Vasiliauskas 2013`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Nolan 2020`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Dorais 2021`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Toole 2016`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA
#
# $`Schulte-Frankenfeld 2021`
#             Name.of.Key.Theme Description.of.Key.Theme Results
# Key.Theme.1                NA                       NA      NA
# Key.Theme.2                NA                       NA      NA
# Key.Theme.3                NA                       NA      NA
# Key.Theme.4                NA                       NA      NA
# Key.Theme.5                NA                       NA      NA
# Key.Theme.6                NA                       NA      NA
# Key.Theme.7                NA                       NA      NA

# %% [markdown]
# # Notes
# - Different Scales
#     - 2 Array-Dims with same values
#     - Results in Dim "Scale.2" only if 2nd scale is present, else: NA
#
#
# # ToDo
# - find solution for value: '3.79 during intervention, 2.04 during follow-up mean'
# - put total data into a list
#
#
# # Array Dims and Dimnames
# Dates of Measuring Time Points
# 	4 x 1
# 	c("Time.Point.0", "Time.Point.1", "Time.Point.2", "Time.Point.3")
# 	c("Date")
# 	Time.Point.0.Date:Time.Point.3.Date
#
# Between-Measuring Time Points' Duration
# 	3 x 1
# 	c("Time.Point.0...1", "Time.Point.0...2", "Time.Point.0...3")
# 	c("Duration.in.Days")
# 	Time.Point.0...1:Duration.in.Days
#
# Intervention and Comparisons
# 	7 x 4
# 	c("Name", "Short.Description", "Delivery.Mode", "Meditation.App", "Sessions.Duration.in.minutes", Frequency.in.times.per.week", "Total.Duration.in.Days")
# 	c("Intervention.1", "Intervention.2", "Intervention.3", "Control")
# 	Name.Intervention 1:Total.Duration.of.Intervention.in.Days.Control.or.Intervention.4
#
# Definition of Outcomes
# 	7 x 1
# 	c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7")
# 	c("Definition")
# 	Outcome.1:Definition
#
# Measures of Outcomes
# 	7 x 3
# 	c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7")
# 	c("Measures.Name", "Start.and.End.Point", "High.or.low.means.resilient")
# 	Outcome.1.Scale.s.or.other.Measure.s.Name:Outcome.7.High.or.low.means.resilient
#
# Means and SDs of Outcomes
# 	4 x 3 x 4 x 7
# 	c("Intervention.1", "Intervention.2", "Intervention.3", "Control"
# 	c("Mean", "SD", "n")
# 	c("T0", "T1", "T2", "T3")
# 	c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7")
# 	Intervention.1.Mean.O1T0:Control.or.Intervention.4.n.in.case.of.period.O7T3
#
# Quantitative Results of Data Analyses
# 	7 x 3 x 3 x 6
# 	c("Outcome.1", "Outcome.2", "Outcome.3", "Outcome.4", "Outcome.5", "Outcome.6", "Outcome.7")
# 	c("P.Value", "Effect.Size", "Effect.Size.CI")
# 	c("T1", "T2", "T3")
# 	c("Int1.X.Int2", "Int1.X.Int3", "Int1.X.Int4", "Int2.X.Int3", "Int2.X.Int4", "Int3.X.Int4")
# 	Outcome.1.P.Value.1x2T1:Outcome.7.Confidence.Interval.of.Effect.Size.3x4T3
#
# Qualitative Results of Data Analyses
# 	7 x 3
# 	c("Key.Theme.1", "Key.Theme.2", "Key.Theme.4", "Key.Theme.5", "Key.Theme.6", "Key.Theme.7")
# 	c("Name.of.Key.Theme", "Description.of.Key.Theme", "Results")
# 	Key.Theme.1:Results
#
# # TEST - Get Studies investigating stress

# %%
my.df.stress <- my.df[my.df$Name.of.Outcome.1 == "Stress" |
                      my.df$Name.of.Outcome.2 == "Stress" |
                      my.df$Name.of.Outcome.3 == "Stress" |
                      my.df$Name.of.Outcome.4 == "Stress" |
                      my.df$Name.of.Outcome.5 == "Stress" |
                      my.df$Name.of.Outcome.6 == "Stress" |
                      my.df$Name.of.Outcome.7 == "Stress",]

# %%
subset(my.df.stress, select = c(Name.of.Outcome.1:Name.of.Outcome.7))

# %%
my.df.stress.id.otcm <- subset(my.df.stress, select = c(Study.ID, Name.of.Outcome.1:Name.of.Outcome.7))
my.df.stress.id.otcm

# %% [markdown]
# # TEST - Convert data frame to array and insert array into it
# ## Create df

# %%
test.name.1 <- 1
test.name.2 <- 2
test.name.3 <- 3
test.name.4 <- 4


test.df <- data.frame(test.name.1,
                      test.name.2,
                      test.name.3,
                      test.name.4
                      )

# %%
test.df

# %% [markdown]
# ## Convert df to array

# %%
arr1 <- array(data = c(unlist(test.df)),
              dim = c(1, 4),
              dimnames = list("Jacob 2022",
                              colnames(test.df)
                              )
)

# %% [markdown]
# ## Split array in to parts

# %%
cut.range.1 <- which(colnames(arr1) == "test.name.1"):which(colnames(arr1) == "test.name.2")

# %%
arr1.1 <- array(data = arr1[, cut.range.1],
                dim = c(1,length(cut.range.1)),
                dimnames = list(rownames(arr1),
                                colnames(arr1)[cut.range.1]
                                )
                )
arr1.1

# %%
cut.range.2 <- which(colnames(arr1) == "test.name.3"):which(colnames(arr1) == "test.name.4")

# %%
arr1.2 <- array(data = arr1[, cut.range.2],
                dim = c(1,length(cut.range.2)),
                dimnames = list(rownames(arr1),
                                colnames(arr1)[cut.range.2]
                                )
                )
arr1.2

# %% [markdown]
# ## Create array that will get inserted

# %%
arr0 <- array(data = 1:4,
              dim = c(2, 2),
              dimnames = list(c("Row.1", "Row.2"),
                              c("Col.1", "Col2"))
              )

# %% [markdown]
# ## Create new array out of these 3

# %%
arr2 <- array(data = c(arr1.1, arr1.2),
              dim = c(dim(arr1.2)[1],
                      dim(arr1.1)[2] + dim(arr1.2)[2]
                      ),
              dimnames = list(rownames(arr1.1),
                              c(colnames(arr1.1),
                                colnames(arr1.2)
                                )
                              )
              )

# possible to combine arrays of different dimension in on array?

# %%
list.1 <- list(arr1.1, arr0, arr1.2)
names(list.1) <- c("arr1.1", "arr0", "arr1.2")
list.1

# %%
arr3 <- array(data = c(list.1, list.1))
arr3
