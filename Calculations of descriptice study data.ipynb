# %% [markdown]
# # # 5114 – Liu 2022

# %%
# install.packages("foreign")
library("foreign")
library("tidyverse")
df <- read.spss("# 5114 – Liu 2022.sav", to.data.frame = TRUE) |> select(c(mindfulness, T2mindfulness, group))
df.mind <- df |> filter(group == "mindfulnees")
df.cont <- df |> filter(group == "control")

# %%
nrow(df.mind); nrow(df.cont)
# Out:
# [1] 22
# [1] 22

# %%
print("mindf")
mean(df.mind$mindfulness); sd(df.mind$mindfulness);
mean(df.mind$T2mindfulness); sd(df.mind$T2mindfulness);
print("cont");
mean(df.cont$mindfulness); sd(df.cont$mindfulness);
mean(df.cont$T2mindfulness); sd(df.cont$T2mindfulness)
# Out:
# [1] "mindf"
# [1] 35.18182
# [1] 6.329345
# [1] 37.68182
# [1] 7.846057
# [1] "cont"
# [1] 40.31818
# [1] 5.204269
# [1] 38.31818
# [1] 5.626353

# %% [markdown]
# # Tsai 2017 - #873

# %%
library("foreign")
library("tidyverse")
# Out:
# Warning message:
# "package 'foreign' was built under R version 4.3.1"
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# prefer dplyr packages
library(conflicted)
conflict_prefer("filter", "dplyr")
conflict_prefer("lag", "dplyr")
# Out:
# [conflicted] Will prefer dplyr::filter over any other package.
# [conflicted] Will prefer dplyr::lag over any other package.

# %%
df <- read.spss("Tsai 2017 - #873.sav", to.data.frame = TRUE)
df
# Out:
#     ID_no NEG_AF_1 NEG_AF_2 NEG_AF_3 POS_AF_1 POS_AF_2 POS_AF_3 MF_Curiosity_1
# 1    1    16       14       10       39       30       24       11
# 2    2    10       10       10       20       14       20       23
# 3    3    12       11       10       13       14       11       14
# 4    4    14       25       22       34       27       29       15
# 5    5    11       11       10       30       25       29        6
# 6    6    13       18       12       37       37       26       19
# 7    9    10       10       11       32       33       35       17
# 8   10    19       11       11       17       17       22       12
# 9   11    10       10       10       20       19       16       15
# 10  12    14       12       10       22       18       16       13
# 11  13    22       10       10       31       41       41        9
# 12  14    30       24       19       31       33       34       19
# 13  15    28       16       12       32       26       17       16
# 14  16    14       11       11       25       15       20        7
# 15  17    10       11       10       27       34       26       21
# 16  18    10       13       10       44       35       35       23
# 17  19    11       10       10       16       15       15        8
# 18  20    10       10       10       15       15       15        4
# 19  21    13       14       13       34       27       25       17
# 20  22    13       14       13       25       24       15        7
# 21  23    10       10       10       18       16       15       10
# 22  24    15       21       12       21       15       15       11
# 23  25    31       16       18       27       21       12        8
# 24  26    12       13       10       24       19       16       14
# 25  27    15       12       14       26       24       24       11
# 26  28    10       10       10       21       19       21       18
# 27  29    15       22       13       17       17       21       22
# 28  30    10       14       10       34       36       41       17
# 29  32    27       27       29       41       36       39       19
# 30  33    15       24       13       28       27       19        3
# ⋮   ⋮     ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮
# 81   84   12       17       11       25       17       28       10
# 82   85   11       11       12       18       19       16       11
# 83   86   13       11       11       38       34       31       14
# 84   87   10       10       10       16       14       10        0
# 85   88   17       14       14       27       27       28       24
# 86   89   10       14       13       28       39       35       12
# 87   90   22       16       19       21       13       23       13
# 88   91   13       13       13       31       35       28       19
# 89   92   15       13       13       23       28       17       17
# 90   93   13       14       12       22       21       16        2
# 91   94   12       13       10       21       18       23       17
# 92   95   10       10       10       25       26       20       17
# 93   96   16       12       13       30       39       32       21
# 94   97   20       11       10       24       19       12        9
# 95   98   12       13       13       18       17       19       18
# 96   99   17       19       15       36       35       42       24
# 97  100   11       10       10       23       20       24       13
# 98  101   11       11       11       24       19       24       10
# 99  102   14       11       10       30       31       35       12
# 100 103   10       12       10       21       19       18       10
# 101 104   10       10       10       20       17       21       18
# 102 105   17       16       15       27       18       22        7
# 103 107   13       14       11       29       33       21       14
# 104 108   11       10       10       36       34       44       19
# 105 109   18       25       13       30       19       29        5
# 106 110   11       15       15       11       10       10        0
# 107 111   16       18       14       37       39       33       15
# 108 112   15       16       12       18       12       16       14
# 109 113   15       23       12       37       31       27       11
# 110 114   10       10       10       16       12       13        0
#     MF_Curiosity_2 MF_Decentering_1 MF_Decentering_2 IND_GRP
# 1   14             11               12               Mindfulness
# 2   24             16               16               Distraction
# 3   10             12               18               Distraction
# 4   21             16               20               Mindfulness
# 5    6             11               16               Distraction
# 6   19             17                9               Mindfulness
# 7   17             24               25               Distraction
# 8   23             10               27               Distraction
# 9   21             14               20               Mindfulness
# 10  14              8                9               Distraction
# 11  17             11               13               Mindfulness
# 12  19             12               15               Distraction
# 13  15             15               11               Mindfulness
# 14  11              4               16               Distraction
# 15  24             18               22               Distraction
# 16  24             18               16               Distraction
# 17  18             17               25               Mindfulness
# 18  20              1               20               Mindfulness
# 19  11             16               19               Distraction
# 20   7             15               16               Mindfulness
# 21  14             18               18               Distraction
# 22  17              9               22               Mindfulness
# 23   4             14               12               Mindfulness
# 24  12              9               12               Distraction
# 25  13             19               18               Mindfulness
# 26  16             13               15               Mindfulness
# 27  15             13               23               Distraction
# 28  24             23               28               Distraction
# 29  15             19               20               Mindfulness
# 30  18             21               25               Distraction
# ⋮   ⋮              ⋮                ⋮                ⋮
# 81  13             10               14               Mindfulness
# 82   3             10                5               Mindfulness
# 83  12              8               15               Distraction
# 84   1              2                7               Distraction
# 85  24             26               25               Distraction
# 86  23              7                3               Mindfulness
# 87  18             12               16               Distraction
# 88  16             23               24               Mindfulness
# 89  15             15               19               Distraction
# 90   3              8               11               Distraction
# 91  21             14               23               Mindfulness
# 92  16             12               14               Distraction
# 93  17             19               20               Mindfulness
# 94   7             11                7               Mindfulness
# 95  20             17               19               Distraction
# 96  24             11               22               Mindfulness
# 97  19             14               18               Distraction
# 98  12             12               15               Mindfulness
# 99  17             14               23               Distraction
# 100 18              9               16               Mindfulness
# 101 20             16               17               Distraction
# 102 12             10               14               Mindfulness
# 103  7             14               13               Distraction
# 104 18             14               21               Mindfulness
# 105 23             20               20               Distraction
# 106  0              0                0               Mindfulness
# 107 15             17               17               Distraction
# 108 15             11               15               Mindfulness
# 109 13             17               19               Distraction
# 110  0              2                7               Mindfulness

# %%
# generate dfs for control and intervention group of the outcome positive affect for t2 and t3 which are pre- and post-tests in our terms
df.mind <- df |> filter(IND_GRP == "Mindfulness") |> select(POS_AF_2, POS_AF_3)
df.cont <- df |> filter(IND_GRP == "Distraction") |> select(POS_AF_2, POS_AF_3)
df.mind
df.cont
# Out:
#    POS_AF_2 POS_AF_3
# 1  30       24
# 2  27       29
# 3  37       26
# 4  19       16
# 5  41       41
# 6  26       17
# 7  15       15
# 8  15       15
# 9  24       15
# 10 15       15
# 11 21       12
# 12 24       24
# 13 19       21
# 14 36       39
# 15 26       29
# 16 18       12
# 17 40       24
# 18 31       35
# 19 19       26
# 20 33       32
# 21 17       27
# 22 28       31
# 23 15       12
# 24 23       22
# 25 25       28
# 26 20       11
# 27 42       39
# 28 35       29
# 29 30       29
# 30 14       13
# 31 21       28
# 32 19       23
# 33 19       13
# 34 29       32
# 35 36       30
# 36 33       32
# 37 34       36
# 38 24       27
# 39 30       30
# 40 17       28
# 41 19       16
# 42 39       35
# 43 35       28
# 44 18       23
# 45 39       32
# 46 19       12
# 47 35       42
# 48 19       24
# 49 19       18
# 50 18       22
# 51 34       44
# 52 10       10
# 53 12       16
# 54 12       13
#    POS_AF_2 POS_AF_3
# 1  14       20
# 2  14       11
# 3  25       29
# 4  33       35
# 5  17       22
# 6  18       16
# 7  33       34
# 8  15       20
# 9  34       26
# 10 35       35
# 11 27       25
# 12 16       15
# 13 19       16
# 14 17       21
# 15 36       41
# 16 27       19
# 17 17       24
# 18 27       15
# 19 25       13
# 20 14       13
# 21 16       17
# 22 33       22
# 23 17       29
# 24 22       22
# 25 48       48
# 26 11       23
# 27 19       16
# 28 26       28
# 29 50       50
# 30 15       17
# 31 16       11
# 32 29       33
# 33 21       21
# 34 34       25
# 35 25       18
# 36 20       32
# 37 21       20
# 38 37       41
# 39 22       17
# 40 14       15
# 41 20       32
# 42 34       31
# 43 14       10
# 44 27       28
# 45 13       23
# 46 28       17
# 47 21       16
# 48 26       20
# 49 17       19
# 50 20       24
# 51 31       35
# 52 17       21
# 53 33       21
# 54 19       29
# 55 39       33
# 56 31       27

# %%
desc.stat.t0.df <- data.frame(
  mean = c(
    mean(df.mind$POS_AF_2),
    mean(df.cont$POS_AF_2)
  ),
  sd = c(
    sd(df.mind$POS_AF_2),
    sd(df.cont$POS_AF_2)
  ),
  n = c(
    sum(!is.na(df.mind$POS_AF_2)),
    sum(!is.na(df.cont$POS_AF_2))
  ),
  row.names = list("Intervention 1", "Intervention 2")
)
desc.stat.t1.df <- data.frame(
  mean = c(
    mean(df.mind$POS_AF_3),
    mean(df.cont$POS_AF_3)
  ),
  sd = c(
    sd(df.mind$POS_AF_3),
    sd(df.cont$POS_AF_3)
  ),
  n = c(
    sum(!is.na(df.mind$POS_AF_3)),
    sum(!is.na(df.cont$POS_AF_3))
  ),
  row.names = list("Intervention 1", "Intervention 2")
)

print("pre-test")
desc.stat.t0.df
cat("\n")
print("post-test")
desc.stat.t1.df
# Out:
# [1] "pre-test"
#                mean     sd       n
# Intervention 1 25.09259 8.716215 54
# Intervention 2 24.08929 8.895917 56
# [1] "post-test"
#                mean     sd       n
# Intervention 1 24.48148 9.036072 54
# Intervention 2 23.94643 8.969483 56
